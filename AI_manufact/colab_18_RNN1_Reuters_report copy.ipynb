# %%
#또한 단어 사용 수와 임베딩 차원의 영향을 분석

import matplotlib.pyplot as plt
import numpy

# 로이터 뉴스 데이터셋 불러오기
from tensorflow import keras
from keras.datasets import reuters
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, SimpleRNN, Dropout, Conv1D, GlobalMaxPooling1D
from keras.preprocessing import sequence
from keras import utils

# seed 값 설정
seed = 0
numpy.random.seed(seed)
#tensorflow.set_random_seed(3)

num_words = 50
embed_dim = 25

# 불러온 데이터를 학습셋, 테스트셋으로 나누기
(X_train, Y_train), (X_test, Y_test) = reuters.load_data(num_words=num_words, test_split=0.2)

# 데이터 확인하기
category = numpy.max(Y_train) + 1
print(category, '카테고리')
print(len(X_train), '학습용 뉴스 기사')
print(len(X_test), '테스트용 뉴스 기사')
print(X_train[0])

# 데이터 전처리
x_train = sequence.pad_sequences(X_train, maxlen=200)
x_test = sequence.pad_sequences(X_test, maxlen=200)
y_train = utils.to_categorical(Y_train)
y_test = utils.to_categorical(Y_test)
print(x_train.shape)
# Out:
# 46 카테고리
# 8982 학습용 뉴스 기사
# 2246 테스트용 뉴스 기사
# [1, 2, 2, 8, 43, 10, 2, 5, 25, 2, 2, 5, 2, 2, 16, 2, 2, 2, 2, 7, 2, 5, 19, 2, 6, 19, 2, 15, 2, 2, 2, 22, 2, 26, 7, 48, 4, 49, 8, 2, 39, 2, 2, 6, 2, 6, 2, 11, 15, 22, 2, 11, 15, 7, 48, 9, 2, 2, 2, 6, 2, 6, 2, 11, 15, 22, 2, 44, 11, 15, 16, 8, 2, 2, 2, 2, 2, 29, 2, 30, 32, 2, 6, 2, 15, 17, 12]
# (8982, 200)

# %%
# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_9 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 68s 696ms/step - accuracy: 0.3481 - loss: 2.6004 - val_accuracy: 0.3620 - val_loss: 2.4209
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 558ms/step - accuracy: 0.3517 - loss: 2.4107 - val_accuracy: 0.3620 - val_loss: 2.4177
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 321ms/step - accuracy: 0.4088 - loss: 2.2632 - val_accuracy: 0.4813 - val_loss: 2.1047
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 345ms/step - accuracy: 0.4684 - loss: 2.0998 - val_accuracy: 0.4866 - val_loss: 2.0755
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.4792 - loss: 2.0676 - val_accuracy: 0.4915 - val_loss: 2.0743
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━
30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 18s 204ms/step - accuracy: 0.5797 - loss: 1.5960 - val_accuracy: 0.5766 - val_loss: 1.6538
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 18s 204ms/step - accuracy: 0.5821 - loss: 1.5813 - val_accuracy: 0.5730 - val_loss: 1.6568

# %%
# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.5766 - loss: 1.6538
#
#  Test Accuracy_model_2: 0.5766

# %%
num_words = 250
embed_dim = 25

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_10 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.3458 - loss: 2.6031 - val_accuracy: 0.3620 - val_loss: 2.4191
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 21s 236ms/step - accuracy: 0.3517 - loss: 2.4115 - val_accuracy: 0.3620 - val_loss: 2.4176
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 28s 312ms/step - accuracy: 0.3902 - loss: 2.3168 - val_accuracy: 0.4760 - val_loss: 2.1072
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 43s 337ms/step - accuracy: 0.4626 - loss: 2.1116 - val_accuracy: 0.4777 - val_loss: 2.0824
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 26s 285ms/step - accuracy: 0.4776 - loss: 2.0628 - val_accuracy: 0.4862 - val_loss: 2.0327
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 22s 246ms/step - accuracy: 0.4870 - loss: 2.0099 - val_accuracy: 0.4969 - val_loss: 2.1460
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - accuracy: 0.4912 - loss: 1.9603 - val_accuracy: 0.5191 - val_loss: 1.9027
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 18s 198ms/step - accuracy: 0.5075 - loss: 1.8916 - val_accuracy: 0.5160 - val_loss: 1.8824
# Epoch 9/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 28s 317ms/step - accuracy: 0.5091 - loss: 1.8751 - val_accuracy: 0.5111 - val_loss: 1.8882
# Epoch 10/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 329ms/step - accuracy: 0.5180 - loss: 1.8490 - val_accuracy: 0.5107 - val_loss: 1.8827
# Epoch 11/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.5189 - loss: 1.8284 - val_accuracy: 0.5280 - val_loss: 1.8294
# Epoch 12/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 27s 301ms/step - accuracy: 0.5355 - loss: 1.7869 - val_accuracy: 0.5334 - val_loss: 1.8195
# Epoch 13/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 44s 330ms/step - accuracy: 0.5441 - loss: 1.7614 - val_accuracy: 0.5432 - val_loss: 1.7792
# Epoch 14/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 326ms/step - accuracy: 0.5431 - loss: 1.7408 - val_accuracy: 0.5472 - val_loss: 1.7692
# Epoch 15/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 25s 283ms/step - accuracy: 0.5522 - loss: 1.7155 - val_accuracy: 0.5485 - val_loss: 1.7525
# Epoch 16/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 18s 196ms/step - accuracy: 0.5583 - loss: 1.6980 - val_accuracy: 0.5543 - val_loss: 1.7278
# Epoch 17/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 18s 200ms/step - accuracy: 0.5580 - loss: 1.6804 - val_accuracy: 0.5597 - val_loss: 1.7187
# Epoch 18/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 23s 251ms/step - accuracy: 0.5677 - loss: 1.6603 - val_accuracy: 0.5610 - val_loss: 1.7020
# Epoch 19/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 218ms/step - accuracy: 0.5707 - loss: 1.6425 - val_accuracy: 0.5592 - val_loss: 1.6834
# Epoch 20/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 222ms/step - accuracy: 0.5743 - loss: 1.6262 - val_accuracy: 0.5797 - val_loss: 1.6586
# Epoch 21/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.5764 - loss: 1.6088 - val_accuracy: 0.5752 - val_loss: 1.6577
# Epoch 22/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 18s 195ms/step - accuracy: 0.5842 - loss: 1.5893 - val_accuracy: 0.5677 - val_loss: 1.6534
# Epoch 23/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 224ms/step - accuracy: 0.5846 - loss: 1.5810 - val_accuracy: 0.5744 - val_loss: 1.6465
# Epoch 24/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 227ms/step - accuracy: 0.5852 - loss: 1.5723 - val_accuracy: 0.5752 - val_loss: 1.6340
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 22s 245ms/step - accuracy: 0.5903 - loss: 1.5566 - val_accuracy: 0.5779 - val_loss: 1.6178
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 24s 262ms/step - accuracy: 0.5923 - loss: 1.5401 - val_accuracy: 0.5810 - val_loss: 1.6396
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 338ms/step - accuracy: 0.5936 - loss: 1.5314 - val_accuracy: 0.5828 - val_loss: 1.6162
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 27s 297ms/step - accuracy: 0.5962 - loss: 1.5238 - val_accuracy: 0.5877 - val_loss: 1.6095
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 23s 258ms/step - accuracy: 0.5982 - loss: 1.5151 - val_accuracy: 0.5864 - val_loss: 1.6173
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 19s 214ms/step - accuracy: 0.6030 - loss: 1.5071 - val_accuracy: 0.5904 - val_loss: 1.6044
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.5904 - loss: 1.6044
#
#  Test Accuracy_model_2: 0.5904

# %%
num_words = 500
embed_dim = 25

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_11 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 293ms/step - accuracy: 0.3470 - loss: 2.5938 - val_accuracy: 0.3620 - val_loss: 2.4182
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 377ms/step - accuracy: 0.3517 - loss: 2.4125 - val_accuracy: 0.3620 - val_loss: 2.4164
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 357ms/step - accuracy: 0.3793 - loss: 2.3209 - val_accuracy: 0.4675 - val_loss: 2.1290
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 380ms/step - accuracy: 0.4734 - loss: 2.1045 - val_accuracy: 0.4871 - val_loss: 2.0757
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 328ms/step - accuracy: 0.4875 - loss: 2.0527 - val_accuracy: 0.5022 - val_loss: 2.0325
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 218ms/step - accuracy: 0.4991 - loss: 2.0224 - val_accuracy: 0.5102 - val_loss: 1.9879
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 217ms/step - accuracy: 0.5073 - loss: 1.9549 - val_accuracy: 0.5223 - val_loss: 1.9189
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 22s 246ms/step - accuracy: 0.5144 - loss: 1.9136 - val_accuracy: 0.5036 - val_loss: 1.9293
# Epoch 9/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 19s 213ms/step - accuracy: 0.5223 - loss: 1.8812 - val_accuracy: 0.5196 - val_loss: 1.8847
# Epoch 10/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 22s 243ms/step - accuracy: 0.5239 - loss: 1.8589 - val_accuracy: 0.5080 - val_loss: 1.8925
# Epoch 11/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 19s 213ms/step - accuracy: 0.5289 - loss: 1.8402 - val_accuracy: 0.5267 - val_loss: 1.8603
# Epoch 12/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 23s 252ms/step - accuracy: 0.5331 - loss: 1.8242 - val_accuracy: 0.5352 - val_loss: 1.8439
# Epoch 13/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.5379 - loss: 1.8082 - val_accuracy: 0.5365 - val_loss: 1.8376
# Epoch 14/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 225ms/step - accuracy: 0.5384 - loss: 1.7972 - val_accuracy: 0.5361 - val_loss: 1.8288
# Epoch 15/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 20s 225ms/step - accuracy: 0.5401 - loss: 1.7851 - val_accuracy: 0.5347 - val_loss: 1.8210
# Epoch 16/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 23s 255ms/step - accuracy: 0.5469 - loss: 1.7655 - val_accuracy: 0.5441 - val_loss: 1.8094
# Epoch 17/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 22s 244ms/step - accuracy: 0.5497 - loss: 1.7538 - val_accuracy: 0.5410 - val_loss: 1.7942
# Epoch 18/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.5517 - loss: 1.7334 - val_accuracy: 0.5557 - val_loss: 1.7543
# Epoch 19/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 28s 311ms/step - accuracy: 0.5589 - loss: 1.7112 - val_accuracy: 0.5561 - val_loss: 1.7648
# Epoch 20/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 24s 268ms/step - accuracy: 0.5607 - loss: 1.7015 - val_accuracy: 0.5592 - val_loss: 1.7429
# Epoch 21/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 25s 283ms/step - accuracy: 0.5628 - loss: 1.6852 - val_accuracy: 0.5606 - val_loss: 1.7268
# Epoch 22/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 41s 458ms/step - accuracy: 0.5697 - loss: 1.6635 - val_accuracy: 0.5677 - val_loss: 1.7138
# Epoch 23/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 54s 602ms/step - accuracy: 0.5695 - loss: 1.6493 - val_accuracy: 0.5597 - val_loss: 1.7169
# Epoch 24/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 378ms/step - accuracy: 0.5717 - loss: 1.6378 - val_accuracy: 0.5757 - val_loss: 1.6854
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 42s 464ms/step - accuracy: 0.5783 - loss: 1.6158 - val_accuracy: 0.5650 - val_loss: 1.6702
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 37s 408ms/step - accuracy: 0.5834 - loss: 1.5966 - val_accuracy: 0.5761 - val_loss: 1.6609
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 40s 443ms/step - accuracy: 0.5855 - loss: 1.5943 - val_accuracy: 0.5761 - val_loss: 1.6516
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 38s 420ms/step - accuracy: 0.5883 - loss: 1.5738 - val_accuracy: 0.5761 - val_loss: 1.6367
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 38s 416ms/step - accuracy: 0.5942 - loss: 1.5562 - val_accuracy: 0.5721 - val_loss: 1.6386
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 26s 290ms/step - accuracy: 0.5845 - loss: 1.5810 - val_accuracy: 0.5788 - val_loss: 1.6309
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.5788 - loss: 1.6309
#
#  Test Accuracy_model_2: 0.5788

# %%
num_words = 1000
embed_dim = 25

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_12 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_12 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 26s 270ms/step - accuracy: 0.3467 - loss: 2.5782 - val_accuracy: 0.3620 - val_loss: 2.4164
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 26s 287ms/step - accuracy: 0.3612 - loss: 2.3678 - val_accuracy: 0.4479 - val_loss: 2.2020
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 359ms/step - accuracy: 0.4625 - loss: 2.1339 - val_accuracy: 0.4831 - val_loss: 2.0943
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 382ms/step - accuracy: 0.4765 - loss: 2.0794 - val_accuracy: 0.4902 - val_loss: 2.0682
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 37s 408ms/step - accuracy: 0.4865 - loss: 2.0538 - val_accuracy: 0.5000 - val_loss: 2.0188
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━
30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 51s 571ms/step - accuracy: 0.5759 - loss: 1.6122 - val_accuracy: 0.5623 - val_loss: 1.6809
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 60s 665ms/step - accuracy: 0.5794 - loss: 1.6053 - val_accuracy: 0.5726 - val_loss: 1.6692
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 7s 98ms/step - accuracy: 0.5726 - loss: 1.6692
#
#  Test Accuracy_model_2: 0.5726

# %%
num_words = 2000
embed_dim = 25

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_13 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 59s 594ms/step - accuracy: 0.3486 - loss: 2.5849 - val_accuracy: 0.3620 - val_loss: 2.4184
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 36s 394ms/step - accuracy: 0.3517 - loss: 2.4132 - val_accuracy: 0.3620 - val_loss: 2.4190
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 359ms/step - accuracy: 0.3517 - loss: 2.4109 - val_accuracy: 0.3620 - val_loss: 2.4179
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 40s 347ms/step - accuracy: 0.4022 - loss: 2.2831 - val_accuracy: 0.4599 - val_loss: 2.1109
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 251ms/step - accuracy: 0.4605 - loss: 2.1122 - val_accuracy: 0.4773 - val_loss: 2.0777
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 355ms/step - accuracy: 0.4693 - loss: 2.0664 - val_accuracy: 0.4858 - val_loss: 2.0499
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 326ms/step - accuracy: 0.4752 - loss: 2.0457 - val_accuracy: 0.4889 - val_loss: 2.0240
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 321ms/step - accuracy: 0.4854 - loss: 2.0042 - val_accuracy: 0.5000 - val_loss: 1.9656
# Epoch 9/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 28s 312ms/step - accuracy: 0.4980 - loss: 1.9346 - val_accuracy: 0.5191 - val_loss: 1.8865
# Epoch 10/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 43s 331ms/step - accuracy: 0.5145 - loss: 1.8713 - val_accuracy: 0.5298 - val_loss: 1.8621
# Epoch 11/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 28s 309ms/step - accuracy: 0.5218 - loss: 1.8394 - val_accuracy: 0.5392 - val_loss: 1.8283
# Epoch 12/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 329ms/step - accuracy: 0.5264 - loss: 1.8122 - val_accuracy: 0.5356 - val_loss: 1.8112
# Epoch 13/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 333ms/step - accuracy: 0.5397 - loss: 1.7812 - val_accuracy: 0.5365 - val_loss: 1.8062
# Epoch 14/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 334ms/step - accuracy: 0.5454 - loss: 1.7571 - val_accuracy: 0.5396 - val_loss: 1.7755
# Epoch 15/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 340ms/step - accuracy: 0.5505 - loss: 1.7268 - val_accuracy: 0.5588 - val_loss: 1.7418
# Epoch 16/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 318ms/step - accuracy: 0.5548 - loss: 1.7105 - val_accuracy: 0.5659 - val_loss: 1.7095
# Epoch 17/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 355ms/step - accuracy: 0.5616 - loss: 1.6797 - val_accuracy: 0.5610 - val_loss: 1.6939
# Epoch 18/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 40s 441ms/step - accuracy: 0.5691 - loss: 1.6631 - val_accuracy: 0.5672 - val_loss: 1.6853
# Epoch 19/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 372ms/step - accuracy: 0.5686 - loss: 1.6351 - val_accuracy: 0.5668 - val_loss: 1.6680
# Epoch 20/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 30s 331ms/step - accuracy: 0.5726 - loss: 1.6250 - val_accuracy: 0.5659 - val_loss: 1.6612
# Epoch 21/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 327ms/step - accuracy: 0.5799 - loss: 1.6142 - val_accuracy: 0.5659 - val_loss: 1.6555
# Epoch 22/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 27s 301ms/step - accuracy: 0.5783 - loss: 1.6015 - val_accuracy: 0.5744 - val_loss: 1.6337
# Epoch 23/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 27s 299ms/step - accuracy: 0.5854 - loss: 1.5847 - val_accuracy: 0.5784 - val_loss: 1.6202
# Epoch 24/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 28s 310ms/step - accuracy: 0.5863 - loss: 1.5711 - val_accuracy: 0.5846 - val_loss: 1.6122
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.5880 - loss: 1.5606 - val_accuracy: 0.5801 - val_loss: 1.6161
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 348ms/step - accuracy: 0.5905 - loss: 1.5550 - val_accuracy: 0.5850 - val_loss: 1.6001
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 27s 304ms/step - accuracy: 0.5956 - loss: 1.5350 - val_accuracy: 0.5833 - val_loss: 1.6085
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 33s 366ms/step - accuracy: 0.5993 - loss: 1.5313 - val_accuracy: 0.5868 - val_loss: 1.6032
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 27s 301ms/step - accuracy: 0.5949 - loss: 1.5261 - val_accuracy: 0.5886 - val_loss: 1.6014
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 27s 302ms/step - accuracy: 0.6008 - loss: 1.5113 - val_accuracy: 0.5890 - val_loss: 1.5904
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.5890 - loss: 1.5904
#
#  Test Accuracy_model_2: 0.5890

# %%
num_words = 50
embed_dim = 50

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding
30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 374ms/step - accuracy: 0.5900 - loss: 1.5608 - val_accuracy: 0.5739 - val_loss: 1.6300
# Epoch 23/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 33s 362ms/step - accuracy: 0.5920 - loss: 1.5487 - val_accuracy: 0.5757 - val_loss: 1.6172
# Epoch 24/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 25s 281ms/step - accuracy: 0.5978 - loss: 1.5400 - val_accuracy: 0.5735 - val_loss: 1.6192
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 356ms/step - accuracy: 0.5975 - loss: 1.5310 - val_accuracy: 0.5886 - val_loss: 1.6075
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 35s 386ms/step - accuracy: 0.6001 - loss: 1.5132 - val_accuracy: 0.5837 - val_loss: 1.6020
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 355ms/step - accuracy: 0.6053 - loss: 1.5025 - val_accuracy: 0.5877 - val_loss: 1.6039
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - accuracy: 0.6041 - loss: 1.4974 - val_accuracy: 0.5922 - val_loss: 1.5944
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 36s 402ms/step - accuracy: 0.6091 - loss: 1.4792 - val_accuracy: 0.5935 - val_loss: 1.5775
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 33s 362ms/step - accuracy: 0.6121 - loss: 1.4745 - val_accuracy: 0.5971 - val_loss: 1.5856
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.5935 - loss: 1.5775
#
#  Test Accuracy_model_2: 0.5935

# %%
num_words = 250
embed_dim = 50

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_15 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_15 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 39s 371ms/step - accuracy: 0.3473 - loss: 2.5691 - val_accuracy: 0.3620 - val_loss: 2.4213
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 349ms/step - accuracy: 0.3517 - loss: 2.4126 - val_accuracy: 0.3620 - val_loss: 2.4149
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 348ms/step - accuracy: 0.4058 - loss: 2.2668 - val_accuracy: 0.4768 - val_loss: 2.1006
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 348ms/step - accuracy: 0.4738 - loss: 2.0878 - val_accuracy: 0.4902 - val_loss: 2.0729
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 339ms/step - accuracy: 0.4857 - loss: 2.0610 - val_accuracy: 0.5027 - val_loss: 2.0210
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 341ms/step - accuracy: 0.4959 - loss: 2.0207 - val_accuracy: 0.5093 - val_loss: 1.9690
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - accuracy: 0.5917 - loss: 1.5949
#
#  Test Accuracy_model_2: 0.5917

# %%
num_words = 500
embed_dim = 50

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_16 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_16 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 54s 532ms/step - accuracy: 0.3489 - loss: 2.5585 - val_accuracy: 0.3620 - val_loss: 2.4179
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 23s 250ms/step - accuracy: 0.3564 - loss: 2.3996 - val_accuracy: 0.4386 - val_loss: 2.2997
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 357ms/step - accuracy: 0.4473 - loss: 2.1694 - val_accuracy: 0.4786 - val_loss: 2.0955
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 27s 300ms/step - accuracy: 0.4811 - loss: 2.0548 - val_accuracy: 0.4875 - val_loss: 2.0249
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 40s 443ms/step - accuracy: 0.4981 - loss: 1.9728 - val_accuracy: 0.5120 - val_loss: 1.9250
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 44s 487ms/step - accuracy: 0.5153 - loss: 1.8797 - val_accuracy: 0.5334 - val_loss: 1.8718
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 35s 385ms/step - accuracy: 0.5264 - loss: 1.8394 - val_accuracy: 0.5347 - val_loss: 1.8406
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 356ms/step - accuracy: 0.5352 - loss: 1.8002 - val_accuracy: 0.5414 - val_loss: 1.8138
# Epoch 9/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 40s 349ms/step - accuracy: 0.5411 - loss: 1.7729 - val_accuracy: 0.5454 - val_loss: 1.7738
# Epoch 10/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 42s 361ms/step - accuracy: 0.5514 - loss: 1.7426 - val_accuracy: 0.5481 - val_loss: 1.7760
# Epoch 11/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 33s 363ms/step - accuracy: 0.5517 - loss: 1.7288 - val_accuracy: 0.5490 - val_loss: 1.7629
# Epoch 12/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 361ms/step - accuracy: 0.5552 - loss: 1.7082 - val_accuracy: 0.5481 - val_loss: 1.7494
# Epoch 13/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 33s 371ms/step - accuracy: 0.5618 - loss: 1.6925 - val_accuracy: 0.5565 - val_loss: 1.7285
# Epoch 14/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 355ms/step - accuracy: 0.5649 - loss: 1.6850 - val_accuracy: 0.5548 - val_loss: 1.7680
# Epoch 15/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 345ms/step - accuracy: 0.5684 - loss: 1.6630 - val_accuracy: 0.5597 - val_loss: 1.6828
# Epoch 16/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 345ms/step - accuracy: 0.5735 - loss: 1.6345 - val_accuracy: 0.5623 - val_loss: 1.6753
# Epoch 17/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 43s 366ms/step - accuracy: 0.5795 - loss: 1.6168 - val_accuracy: 0.5686 - val_loss: 1.6532
# Epoch 18/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 33s 366ms/step - accuracy: 0.5821 - loss: 1.5951 - val_accuracy: 0.5712 - val_loss: 1.6398
# Epoch 19/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 33s 367ms/step - accuracy: 0.5851 - loss: 1.5803 - val_accuracy: 0.5748 - val_loss: 1.6322
# Epoch 20/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 350ms/step - accuracy: 0.5926 - loss: 1.5615 - val_accuracy: 0.5748 - val_loss: 1.6284
# Epoch 21/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 44s 382ms/step - accuracy: 0.5943 - loss: 1.5569 - val_accuracy: 0.5761 - val_loss: 1.6165
# Epoch 22/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 355ms/step - accuracy: 0.5984 - loss: 1.5474 - val_accuracy: 0.5775 - val_loss: 1.6195
# Epoch 23/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 39s 438ms/step - accuracy: 0.5973 - loss: 1.5387 - val_accuracy: 0.5784 - val_loss: 1.6126
# Epoch 24/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 36s 393ms/step - accuracy: 0.6028 - loss: 1.5233 - val_accuracy: 0.5877 - val_loss: 1.6088
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 36s 399ms/step - accuracy: 0.6016 - loss: 1.5115 - val_accuracy: 0.5868 - val_loss: 1.5913
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 36s 399ms/step - accuracy: 0.6037 - loss: 1.5021 - val_accuracy: 0.5877 - val_loss: 1.5881
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 37s 405ms/step - accuracy: 0.6069 - loss: 1.4917 - val_accuracy: 0.5859 - val_loss: 1.5886
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 36s 400ms/step - accuracy: 0.6091 - loss: 1.4799 - val_accuracy: 0.5926 - val_loss: 1.5853
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 356ms/step - accuracy: 0.6082 - loss: 1.4737 - val_accuracy: 0.5886 - val_loss: 1.5858
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 34s 374ms/step - accuracy: 0.6129 - loss: 1.4632 - val_accuracy: 0.5917 - val_loss: 1.5788
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.5917 - loss: 1.5788
#
#  Test Accuracy_model_2: 0.5917

# %%
num_words = 1000
embed_dim = 50

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding
30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 47s 521ms/step - accuracy: 0.6008 - loss: 1.5272 - val_accuracy: 0.5882 - val_loss: 1.6021
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 51s 560ms/step - accuracy: 0.6052 - loss: 1.5093 - val_accuracy: 0.5810 - val_loss: 1.6062
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 46s 517ms/step - accuracy: 0.6086 - loss: 1.4922 - val_accuracy: 0.5886 - val_loss: 1.5844
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 40s 439ms/step - accuracy: 0.6086 - loss: 1.4849 - val_accuracy: 0.5904 - val_loss: 1.5780
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 38s 425ms/step - accuracy: 0.6121 - loss: 1.4640 - val_accuracy: 0.5895 - val_loss: 1.5994
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 45s 466ms/step - accuracy: 0.6121 - loss: 1.4664 - val_accuracy: 0.5922 - val_loss: 1.5837
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 69s 321ms/step - accuracy: 0.6161 - loss: 1.4550 - val_accuracy: 0.5931 - val_loss: 1.5718
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.5931 - loss: 1.5718
#
#  Test Accuracy_model_2: 0.5931

# %%
num_words = 2000
embed_dim = 50

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_18 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_18 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 29s 305ms/step - accuracy: 0.3421 - loss: 2.5857 - val_accuracy: 0.3620 - val_loss: 2.4130
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 33s 363ms/step - accuracy: 0.4262 - loss: 2.2152 - val_accuracy: 0.4853 - val_loss: 2.0859
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 35s 388ms/step - accuracy: 0.4773 - loss: 2.0768 - val_accuracy: 0.4777 - val_loss: 2.0968
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 356ms/step - accuracy: 0.4859 - loss: 2.0408 - val_accuracy: 0.4933 - val_loss: 2.0366
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 40s 340ms/step - accuracy: 0.4855 - loss: 1.9994 - val_accuracy: 0.5165 - val_loss: 1.9307
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 31s 340ms/step - accuracy: 0.5039 - loss: 1.9096 - val_accuracy: 0.5098 - val_loss: 1.9039
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 32s 360ms/step - accuracy: 0.5132 - loss: 1.8741 - val_accuracy: 0.5178 - val_loss: 1.8981
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.5944 - loss: 1.5621
#
#  Test Accuracy_model_2: 0.5944

# %%
num_words = 50
embed_dim = 100

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_19 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_19 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 503ms/step - accuracy: 0.3431 - loss: 2.5873 - val_accuracy: 0.3620 - val_loss: 2.3701
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 42s 467ms/step - accuracy: 0.4447 - loss: 2.1689 - val_accuracy: 0.4768 - val_loss: 2.1011
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 42s 468ms/step - accuracy: 0.4738 - loss: 2.0817 - val_accuracy: 0.4840 - val_loss: 2.0789
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 44s 491ms/step - accuracy: 0.4929 - loss: 2.0458 - val_accuracy: 0.5138 - val_loss: 2.0316
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 42s 472ms/step - accuracy: 0.5046 - loss: 2.0202 - val_accuracy: 0.5196 - val_loss: 2.0135
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 45s 505ms/step - accuracy: 0.5107 - loss: 1.9875 - val_accuracy: 0.5183 - val_loss: 1.9774
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 549ms/step - accuracy: 0.5122 - loss: 1.9479 - val_accuracy: 0.5223 - val_loss: 1.9388
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 546ms/step - accuracy: 0.5176 - loss: 1.8773 - val_accuracy: 0.5263 - val_loss: 1.8484
# Epoch 9/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 84s 568ms/step - accuracy: 0.5364 - loss: 1.7860 - val_accuracy: 0.5423 - val_loss: 1.7864
# Epoch 10/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 547ms/step - accuracy: 0.5492 - loss: 1.7361 - val_accuracy: 0.5588 - val_loss: 1.7456
# Epoch 11/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 51s 565ms/step - accuracy: 0.5590 - loss: 1.6994 - val_accuracy: 0.5663 - val_loss: 1.7214
# Epoch 12/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 51s 563ms/step - accuracy: 0.5665 - loss: 1.6702 - val_accuracy: 0.5606 - val_loss: 1.6937
# Epoch 13/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 48s 537ms/step - accuracy: 0.5758 - loss: 1.6354 - val_accuracy: 0.5557 - val_loss: 1.7051
# Epoch 14/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 541ms/step - accuracy: 0.5807 - loss: 1.6096 - val_accuracy: 0.5663 - val_loss: 1.6646
# Epoch 15/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 558ms/step - accuracy: 0.5818 - loss: 1.5979 - val_accuracy: 0.5681 - val_loss: 1.6404
# Epoch 16/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 559ms/step - accuracy: 0.5870 - loss: 1.5783 - val_accuracy: 0.5717 - val_loss: 1.6422
# Epoch 17/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 551ms/step - accuracy: 0.5857 - loss: 1.5901 - val_accuracy: 0.5712 - val_loss: 1.6206
# Epoch 18/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 53s 594ms/step - accuracy: 0.5956 - loss: 1.5519 - val_accuracy: 0.5806 - val_loss: 1.6187
# Epoch 19/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 549ms/step - accuracy: 0.5990 - loss: 1.5380 - val_accuracy: 0.5859 - val_loss: 1.6055
# Epoch 20/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 546ms/step - accuracy: 0.6039 - loss: 1.5165 - val_accuracy: 0.5882 - val_loss: 1.5895
# Epoch 21/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 541ms/step - accuracy: 0.6100 - loss: 1.4976 - val_accuracy: 0.5913 - val_loss: 1.5832
# Epoch 22/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 559ms/step - accuracy: 0.6106 - loss: 1.4856 - val_accuracy: 0.5984 - val_loss: 1.5749
# Epoch 23/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 559ms/step - accuracy: 0.6145 - loss: 1.4732 - val_accuracy: 0.5948 - val_loss: 1.5690
# Epoch 24/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 550ms/step - accuracy: 0.6182 - loss: 1.4565 - val_accuracy: 0.5984 - val_loss: 1.5551
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 558ms/step - accuracy: 0.6217 - loss: 1.4432 - val_accuracy: 0.6028 - val_loss: 1.5614
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 540ms/step - accuracy: 0.6227 - loss: 1.4276 - val_accuracy: 0.6082 - val_loss: 1.5398
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 553ms/step - accuracy: 0.6268 - loss: 1.4201 - val_accuracy: 0.6006 - val_loss: 1.5500
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 556ms/step - accuracy: 0.6261 - loss: 1.4080 - val_accuracy: 0.6002 - val_loss: 1.5515
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 51s 563ms/step - accuracy: 0.6315 - loss: 1.3938 - val_accuracy: 0.5966 - val_loss: 1.5581
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 557ms/step - accuracy: 0.6295 - loss: 1.3853 - val_accuracy: 0.6024 - val_loss: 1.5488
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.6082 - loss: 1.5398
#
#  Test Accuracy_model_2: 0.6082

# %%
num_words = 250
embed_dim = 100

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_20 (Embedding)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_20 (LSTM)                  │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 53s 553ms/step - accuracy: 0.3454 - loss: 2.5469 - val_accuracy: 0.3620 - val_loss: 2.4137
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 547ms/step - accuracy: 0.4319 - loss: 2.2050 - val_accuracy: 0.4831 - val_loss: 2.0961
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 48s 537ms/step - accuracy: 0.4790 - loss: 2.0710 - val_accuracy: 0.4987 - val_loss: 2.0541
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 559ms/step - accuracy: 0.4997 - loss: 2.0197 - val_accuracy: 0.5093 - val_loss: 1.9968
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 47s 526ms/step - accuracy: 0.5127 - loss: 1.9284 - val_accuracy: 0.5098 - val_loss: 1.8977
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 540ms/step - accuracy: 0.5246 - loss: 1.8430 - val_accuracy: 0.5214 - val_loss: 1.8639
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 48s 532ms/step - accuracy: 0.5343 - loss: 1.8026 - val_accuracy: 0.5370 - val_loss: 1.8162
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 48s 529ms/step - accuracy: 0.5431 - loss: 1.7509 - val_accuracy: 0.5485 - val_loss: 1.7728
# Epoch 9/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 47s 524ms/step - accuracy: 0.5504 - loss: 1.7227 - val_accuracy: 0.5508 - val_loss: 1.7616
# Epoch 10/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 51s 563ms/step - accuracy: 0.5554 - loss: 1.6996 - val_accuracy: 0.5472 - val_loss: 1.7348
# Epoch 11/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 543ms/step - accuracy: 0.5596 - loss: 1.6793 - val_accuracy: 0.5516 - val_loss: 1.7275
# Epoch 12/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 50s 552ms/step - accuracy: 0.5650 - loss: 1.6625 - val_accuracy: 0.5654 - val_loss: 1.6958
# Epoch 13/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 541ms/step - accuracy: 0.5744 - loss: 1.6342 - val_accuracy: 0.5654 - val_loss: 1.6844
# Epoch 14/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 48s 537ms/step - accuracy: 0.5821 - loss: 1.6101 - val_accuracy: 0.5739 - val_loss: 1.6558
# Epoch 15/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 48s 539ms/step - accuracy: 0.5834 - loss: 1.5898 - val_accuracy: 0.5721 - val_loss: 1.6524
# Epoch 16/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 48s 535ms/step - accuracy: 0.5896 - loss: 1.5697 - val_accuracy: 0.5730 - val_loss: 1.6377
# Epoch 17/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 49s 544ms/step - accuracy: 0.5978 - loss: 1.5545 - val_accuracy: 0.5761 - val_loss: 1.6169
# Epoch 18/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 47s 525ms/step - accuracy: 0.5989 - loss: 1.5379 - val_accuracy: 0.5824 - val_loss: 1.6135
# Epoch 19/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.6011 - loss: 1.5223

# %%
num_words = 50
embed_dim = 200

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']

# %%
num_words = 250
embed_dim = 200

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']

# %%
num_words = 50
embed_dim = 400

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']

# %%
num_words = 250
embed_dim = 400

# 모델의 설정 (model_2 = LSTM) 
model_2 = Sequential()
model_2.add(Embedding(num_words, embed_dim))
model_2.add(LSTM(100, activation='tanh', dropout=0.3))
model_2.add(Dense(46, activation='softmax'))

model_2.summary()

model_2.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

checkpoint_cb_2 = keras.callbacks.ModelCheckpoint('best_model_2_lstm.keras',
                                                save_best_only=True)

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)

history_2 = model_2.fit(x_train, y_train, batch_size=100, epochs=30,
                    validation_data=(x_test, y_test),
                    callbacks=[checkpoint_cb_2, early_stopping_cb])

# 테스트 정확도 출력
print("\n Test Accuracy_model_2: %.4f" % (model_2.evaluate(x_test, y_test)[1]))

# 테스트 셋의 오차
y_vloss_2 = history_2.history['val_loss']

# 학습셋의 오차
y_loss_2 = history_2.history['loss']
