# %% [markdown]
# # LSTM과 GRU 셀

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-mldl/blob/master/9-3.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %% [markdown]
# ## LSTM 신경망 훈련하기

# %%
from tensorflow.keras.datasets import imdb
from sklearn.model_selection import train_test_split

(train_input, train_target), (test_input, test_target) = imdb.load_data(
    num_words=500)

train_input, val_input, train_target, val_target = train_test_split(
    train_input, train_target, test_size=0.2, random_state=42)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

train_seq = pad_sequences(train_input, maxlen=100)
val_seq = pad_sequences(val_input, maxlen=100)

# %%
from tensorflow import keras

model = keras.Sequential()

model.add(keras.layers.Embedding(500, 16, input_length=100))
model.add(keras.layers.LSTM(8))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model.compile(optimizer=rmsprop, loss='binary_crossentropy',
              metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-lstm-model.keras',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history = model.fit(train_seq, train_target, epochs=100, batch_size=64,
                    validation_data=(val_seq, val_target),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.5231 - loss: 0.6928 - val_accuracy: 0.5678 - val_loss: 0.6922
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5808 - loss: 0.6917 - val_accuracy: 0.6080 - val_loss: 0.6905
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6182 - loss: 0.6893 - val_accuracy: 0.6294 - val_loss: 0.6863
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6330 - loss: 0.6836 - val_accuracy: 0.6722 - val_loss: 0.6705
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6754 - loss: 0.6564 - val_accuracy: 0.7042 - val_loss: 0.6067
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7137 - loss: 0.5981 - val_accuracy: 0.7290 - val_loss: 0.5800
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7376 - loss: 0.5704 - val_accuracy: 0.7496 - val_loss: 0.5567
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7494 - loss: 0.5509 - val_accuracy: 0.7470 - val_loss: 0.5436
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7656 - loss: 0.5305 - val_accuracy: 0.7598 - val_loss: 0.5278
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7746 - loss: 0.5135 - val_accuracy: 0.7710 - val_loss: 0.5129
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7796 - loss: 0.4992 - val_accuracy: 0.7768 - val_loss: 0.4993
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7830 - loss: 0.4920 - val_accuracy: 0.7772 - val_loss: 0.4903
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7899 - loss: 0.4801 - val_accuracy: 0.7734 - val_loss: 0.4875
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7916 - loss: 0.4682 - val_accuracy: 0.7816 - val_loss: 0.4755
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8016 - loss: 0.4566 - val_accuracy: 0.7844 - val_loss: 0.4701
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.7977 - loss: 0.4571 - val_accuracy: 0.7868 - val_loss: 0.4622
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8025 - loss: 0.4439 - val_accuracy: 0.7892 - val_loss: 0.4578
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8066 - loss: 0.4413 - val_accuracy: 0.7862 - val_loss: 0.4578
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8039 - loss: 0.4363 - val_accuracy: 0.7896 - val_loss: 0.4514
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8082 - loss: 0.4344 - val_accuracy: 0.7898 - val_loss: 0.4495
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8089 - loss: 0.4300 - val_accuracy: 0.7878 - val_loss: 0.4541
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8117 - loss: 0.4255 - val_accuracy: 0.7944 - val_loss: 0.4439
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8127 - loss: 0.4237 - val_accuracy: 0.7920 - val_loss: 0.4443
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8136 - loss: 0.4205 - val_accuracy: 0.7946 - val_loss: 0.4412
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8099 - loss: 0.4252 - val_accuracy: 0.7958 - val_loss: 0.4394
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8143 - loss: 0.4191 - val_accuracy: 0.7958 - val_loss: 0.4387
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8140 - loss: 0.4188 - val_accuracy: 0.7902 - val_loss: 0.4417
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8102 - loss: 0.4215 - val_accuracy: 0.7874 - val_loss: 0.4457
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8159 - loss: 0.4163 - val_accuracy: 0.7872 - val_loss: 0.4460

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# ## 순환 층에 드롭아웃 적용하기

# %%
model2 = keras.Sequential()

model2.add(keras.layers.Embedding(500, 16, input_length=100))
model2.add(keras.layers.LSTM(8, dropout=0.3))
model2.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model2.compile(optimizer=rmsprop, loss='binary_crossentropy',
               metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-dropout-model.keras',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history = model2.fit(train_seq, train_target, epochs=100, batch_size=64,
                     validation_data=(val_seq, val_target),
                     callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.5143 - loss: 0.6930 - val_accuracy: 0.5488 - val_loss: 0.6926
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5512 - loss: 0.6923 - val_accuracy: 0.5908 - val_loss: 0.6917
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5672 - loss: 0.6912 - val_accuracy: 0.6090 - val_loss: 0.6900
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5960 - loss: 0.6893 - val_accuracy: 0.6208 - val_loss: 0.6870
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6186 - loss: 0.6854 - val_accuracy: 0.6442 - val_loss: 0.6808
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6363 - loss: 0.6783 - val_accuracy: 0.6684 - val_loss: 0.6668
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6650 - loss: 0.6591 - val_accuracy: 0.7060 - val_loss: 0.6237
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7116 - loss: 0.6061 - val_accuracy: 0.7220 - val_loss: 0.5689
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7296 - loss: 0.5653 - val_accuracy: 0.7404 - val_loss: 0.5465
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7373 - loss: 0.5457 - val_accuracy: 0.7448 - val_loss: 0.5318
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7533 - loss: 0.5248 - val_accuracy: 0.7602 - val_loss: 0.5147
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7684 - loss: 0.5047 - val_accuracy: 0.7680 - val_loss: 0.4998
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7714 - loss: 0.4920 - val_accuracy: 0.7744 - val_loss: 0.4859
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.7802 - loss: 0.4788 - val_accuracy: 0.7780 - val_loss: 0.4752
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7867 - loss: 0.4698 - val_accuracy: 0.7794 - val_loss: 0.4675
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7922 - loss: 0.4584 - val_accuracy: 0.7802 - val_loss: 0.4710
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7951 - loss: 0.4521 - val_accuracy: 0.7856 - val_loss: 0.4597
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7995 - loss: 0.4475 - val_accuracy: 0.7862 - val_loss: 0.4555
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8003 - loss: 0.4426 - val_accuracy: 0.7888 - val_loss: 0.4489
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8072 - loss: 0.4325 - val_accuracy: 0.7946 - val_loss: 0.4448
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8047 - loss: 0.4368 - val_accuracy: 0.7938 - val_loss: 0.4450
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8051 - loss: 0.4328 - val_accuracy: 0.7972 - val_loss: 0.4408
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8014 - loss: 0.4377 - val_accuracy: 0.7976 - val_loss: 0.4409
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8089 - loss: 0.4319 - val_accuracy: 0.7974 - val_loss: 0.4391
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8055 - loss: 0.4285 - val_accuracy: 0.7950 - val_loss: 0.4416
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8061 - loss: 0.4262 - val_accuracy: 0.7958 - val_loss: 0.4417
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8068 - loss: 0.4235 - val_accuracy: 0.8004 - val_loss: 0.4358
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8103 - loss: 0.4213 - val_accuracy: 0.7968 - val_loss: 0.4349
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8087 - loss: 0.4212 - val_accuracy: 0.7998 - val_loss: 0.4348
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8103 - loss: 0.4204 - val_accuracy: 0.7984 - val_loss: 0.4402
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8134 - loss: 0.4193 - val_accuracy: 0.8014 - val_loss: 0.4347
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8107 - loss: 0.4209 - val_accuracy: 0.8038 - val_loss: 0.4326
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8139 - loss: 0.4130 - val_accuracy: 0.7924 - val_loss: 0.4404
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8148 - loss: 0.4128 - val_accuracy: 0.8012 - val_loss: 0.4325
# Epoch 35/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8074 - loss: 0.4190 - val_accuracy: 0.8020 - val_loss: 0.4315
# Epoch 36/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8080 - loss: 0.4155 - val_accuracy: 0.8006 - val_loss: 0.4307
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8130 - loss: 0.4137 - val_accuracy: 0.8004 - val_loss: 0.4347
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8107 - loss: 0.4194 - val_accuracy: 0.8036 - val_loss: 0.4317
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8102 - loss: 0.4135 - val_accuracy: 0.7980 - val_loss: 0.4332

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# ## 2개의 층을 연결하기

# %%
model3 = keras.Sequential()

model3.add(keras.layers.Embedding(500, 16, input_length=100))
model3.add(keras.layers.LSTM(8, dropout=0.3, return_sequences=True))
model3.add(keras.layers.LSTM(8, dropout=0.3))
model3.add(keras.layers.Dense(1, activation='sigmoid'))

model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model3.compile(optimizer=rmsprop, loss='binary_crossentropy',
               metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-2rnn-model.keras',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history = model3.fit(train_seq, train_target, epochs=100, batch_size=64,
                     validation_data=(val_seq, val_target),
                     callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.5129 - loss: 0.6929 - val_accuracy: 0.5346 - val_loss: 0.6920
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.5710 - loss: 0.6903 - val_accuracy: 0.6592 - val_loss: 0.6791
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6501 - loss: 0.6639 - val_accuracy: 0.6930 - val_loss: 0.6013
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7070 - loss: 0.5965 - val_accuracy: 0.7292 - val_loss: 0.5549
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.7365 - loss: 0.5510 - val_accuracy: 0.7458 - val_loss: 0.5229
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7511 - loss: 0.5239 - val_accuracy: 0.7576 - val_loss: 0.5058
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7648 - loss: 0.5074 - val_accuracy: 0.7622 - val_loss: 0.4980
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7711 - loss: 0.4938 - val_accuracy: 0.7678 - val_loss: 0.4889
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7777 - loss: 0.4840 - val_accuracy: 0.7740 - val_loss: 0.4769
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7768 - loss: 0.4826 - val_accuracy: 0.7824 - val_loss: 0.4688
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7825 - loss: 0.4780 - val_accuracy: 0.7808 - val_loss: 0.4689
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7866 - loss: 0.4686 - val_accuracy: 0.7800 - val_loss: 0.4679
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7921 - loss: 0.4638 - val_accuracy: 0.7846 - val_loss: 0.4591
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7929 - loss: 0.4551 - val_accuracy: 0.7796 - val_loss: 0.4658
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7934 - loss: 0.4571 - val_accuracy: 0.7900 - val_loss: 0.4551
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7938 - loss: 0.4590 - val_accuracy: 0.7888 - val_loss: 0.4524
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7943 - loss: 0.4530 - val_accuracy: 0.7888 - val_loss: 0.4533
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7941 - loss: 0.4579 - val_accuracy: 0.7930 - val_loss: 0.4500
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7969 - loss: 0.4503 - val_accuracy: 0.7886 - val_loss: 0.4514
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7990 - loss: 0.4488 - val_accuracy: 0.7904 - val_loss: 0.4512
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7996 - loss: 0.4431 - val_accuracy: 0.7904 - val_loss: 0.4473
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8021 - loss: 0.4467 - val_accuracy: 0.7858 - val_loss: 0.4578
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8055 - loss: 0.4364 - val_accuracy: 0.7924 - val_loss: 0.4450
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7980 - loss: 0.4449 - val_accuracy: 0.7896 - val_loss: 0.4458
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8031 - loss: 0.4412 - val_accuracy: 0.7898 - val_loss: 0.4473
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8064 - loss: 0.4362 - val_accuracy: 0.7858 - val_loss: 0.4546

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# ## GRU 신경망 훈련하기

# %%
model4 = keras.Sequential()

model4.add(keras.layers.Embedding(500, 16, input_length=100))
model4.add(keras.layers.GRU(8))
model4.add(keras.layers.Dense(1, activation='sigmoid'))

model4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate=1e-4)
model4.compile(optimizer=rmsprop, loss='binary_crossentropy',
               metrics=['accuracy'])

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-gru-model.keras',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)

history = model4.fit(train_seq, train_target, epochs=100, batch_size=64,
                     validation_data=(val_seq, val_target),
                     callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.5080 - loss: 0.6930 - val_accuracy: 0.5436 - val_loss: 0.6920
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5596 - loss: 0.6914 - val_accuracy: 0.5632 - val_loss: 0.6900
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5815 - loss: 0.6888 - val_accuracy: 0.5798 - val_loss: 0.6868
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6028 - loss: 0.6848 - val_accuracy: 0.5912 - val_loss: 0.6822
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6077 - loss: 0.6794 - val_accuracy: 0.5970 - val_loss: 0.6758
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6195 - loss: 0.6715 - val_accuracy: 0.6070 - val_loss: 0.6672
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6368 - loss: 0.6601 - val_accuracy: 0.6222 - val_loss: 0.6548
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.6421 - loss: 0.6482 - val_accuracy: 0.6404 - val_loss: 0.6384
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6572 - loss: 0.6274 - val_accuracy: 0.6628 - val_loss: 0.6148
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6842 - loss: 0.5981 - val_accuracy: 0.7022 - val_loss: 0.5757
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7200 - loss: 0.5501 - val_accuracy: 0.7460 - val_loss: 0.5165
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7661 - loss: 0.4898 - val_accuracy: 0.7612 - val_loss: 0.4946
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7744 - loss: 0.4747 - val_accuracy: 0.7682 - val_loss: 0.4809
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7800 - loss: 0.4698 - val_accuracy: 0.7782 - val_loss: 0.4701
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7950 - loss: 0.4509 - val_accuracy: 0.7790 - val_loss: 0.4664
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7987 - loss: 0.4449 - val_accuracy: 0.7850 - val_loss: 0.4607
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8003 - loss: 0.4377 - val_accuracy: 0.7880 - val_loss: 0.4566
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8027 - loss: 0.4396 - val_accuracy: 0.7912 - val_loss: 0.4524
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8067 - loss: 0.4349 - val_accuracy: 0.7906 - val_loss: 0.4521
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8090 - loss: 0.4295 - val_accuracy: 0.7846 - val_loss: 0.4614
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8051 - loss: 0.4334 - val_accuracy: 0.7904 - val_loss: 0.4511
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8096 - loss: 0.4268 - val_accuracy: 0.7922 - val_loss: 0.4498
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8073 - loss: 0.4278 - val_accuracy: 0.7936 - val_loss: 0.4452
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8058 - loss: 0.4293 - val_accuracy: 0.7954 - val_loss: 0.4447
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8117 - loss: 0.4250 - val_accuracy: 0.7894 - val_loss: 0.4469
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8123 - loss: 0.4203 - val_accuracy: 0.7942 - val_loss: 0.4448
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8128 - loss: 0.4218 - val_accuracy: 0.7828 - val_loss: 0.4616

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# ## 마무리

# %%
test_seq = pad_sequences(test_input, maxlen=100)

rnn_model = keras.models.load_model('best-gru-model.keras')

rnn_model.evaluate(test_seq, test_target)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7961 - loss: 0.4415
# [0.4412107765674591, 0.7953199744224548]
